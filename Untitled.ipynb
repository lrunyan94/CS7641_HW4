# %%
import mdptoolbox.example

# %%
P, R = mdptoolbox.example.forest()
vi = mdptoolbox.mdp.ValueIteration(P,R,0.9)
vi.run()
vi.policy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2468/2807419167.py in <module>
# ----> 1 P, R = mdptoolbox.example.forest()
#       2 vi = mdptoolbox.mdp.ValueIteration(P,R,0.9)
#       3 vi.run()
#       4 vi.policy
#
# NameError: name 'mdptoolbox' is not defined

# %%
import gym

# %%
env = gym.make('MountainCar-v0')
env.reset()
for _ in range(2000):
    env.render()
    env.step(env.action_space.sample())
env.close()

# %%
import hiive.mdptoolbox as mdptoolbox

# %%
env = gym.make('Taxi-v3')
states = env.observation_space.n
actions = env.action_space.n
P2, R2 = build_matrix(env, states, actions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2468/3617170690.py in <module>
#       2 states = env.observation_space.n
#       3 actions = env.action_space.n
# ----> 4 P2, R2 = build_matrix(env, states, actions)
#
# NameError: name 'build_matrix' is not defined
